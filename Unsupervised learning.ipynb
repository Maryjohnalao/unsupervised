# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('CC GENERAL.csv')

# %%
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
data.tail()
# Out:
#      CUST_ID     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8945  C19186   28.493517           1.000000     291.12              0.00
# 8946  C19187   19.183215           1.000000     300.00              0.00
# 8947  C19188   23.398673           0.833333     144.40              0.00
# 8948  C19189   13.457564           0.833333       0.00              0.00
# 8949  C19190  372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 8945                    0.000000                          0.833333
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
data.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
data.shape
# Out:
# (8950, 18)

# %%
data.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
data['CREDIT_LIMIT'] = data['CREDIT_LIMIT'].interpolate(method = 'linear')

# %%
data.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          0
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
data['MINIMUM_PAYMENTS'] = data['MINIMUM_PAYMENTS'].interpolate(method = 'linear')

# %%
data.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(data[['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES','INSTALLMENTS_PURCHASES','CASH_ADVANCE','PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY', 'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX', 'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT', 'TENURE']]))
z
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     0.731989           0.249434   0.424900          0.356934
# 1     0.786961           0.134325   0.469552          0.356934
# 2     0.447135           0.518084   0.107668          0.108889
# 3     0.049099           1.016953   0.232058          0.546189
# 4     0.358775           0.518084   0.462063          0.347294
# ...        ...                ...        ...               ...
# 8945  0.737950           0.518084   0.333293          0.356934
# 8946  0.742423           0.518084   0.329136          0.356934
# 8947  0.740398           0.185477   0.401965          0.356934
# 8948  0.745174           0.185477   0.469552          0.356934
# 8949  0.572575           0.889033   0.042146          0.301732
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                   0.349079      0.466786             0.806490
# 1                   0.454576      2.605605             1.221758
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
data.shape
# Out:
# (8950, 18)

# %%
num_var = list(data.select_dtypes(include = ['float64', 'int64']).columns)
data_duplicate = data.copy()

# %%
import matplotlib.pyplot as plt
import seaborn as sb

plt.figure(figsize = (20,40))
x = 1
for column in num_var:
    plt.subplot(9,3,x)
    sb.distplot(data_duplicate[column])
    plt.title('Distribution{}'.format(column), fontsize=10, color = 'red', fontweight = 'bold', y=0.90)
    x += 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
model = AgglomerativeClustering(n_clusters=5, affinity = 'euclidean', linkage ='complete')
from sklearn.metrics import silhouette_score as ss

# %%
data.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
data = data.drop(['CUST_ID'], axis =1)

# %%
data.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
#finding the number of Agglomerative clusters
Agg_score = []

for i in range(2,6):
    model = AgglomerativeClustering(n_clusters = i, affinity = 'euclidean', linkage ='ward')
    pre = model.fit_predict(data)
    Agg_score = ss(data, pre)
    print(i, 'score is : ', Agg_score)
# Out:
# 2 score is :  0.32962899640313886
# 3 score is :  0.33466245935925626
# 4 score is :  0.33061544782289654
# 5 score is :  0.33885755545008

# %%
from sklearn.cluster import AgglomerativeClustering #Importing our clustering algorithm : Agglomerative

model=AgglomerativeClustering(n_clusters=5, affinity='euclidean', linkage='ward')

clust_labels=model.fit_predict(data)  #Applying agglomerative algorithm with 5 clusters, using euclidean distance as a metric

# %%
data['CLUSTER'] = clust_labels

# %%
data.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
# data.drop(['cluster'], axis = 1)

# %%
cluster1 = data[data.CLUSTER ==0]
cluster2 = data[data.CLUSTER == 1]
cluster3 = data[data.CLUSTER == 2]
cluster4 = data[data.CLUSTER == 3]
cluster5 = data[data.CLUSTER == 4]

# %%
print(cluster1['CLUSTER'].value_counts())
print(cluster2['CLUSTER'].value_counts())
print(cluster3['CLUSTER'].value_counts())
print(cluster4['CLUSTER'].value_counts())
print(cluster5['CLUSTER'].value_counts())
# Out:
# 0    3077
# Name: CLUSTER, dtype: int64
# 1    729
# Name: CLUSTER, dtype: int64
# 2    23
# Name: CLUSTER, dtype: int64
# 3    5052
# Name: CLUSTER, dtype: int64
# 4    69
# Name: CLUSTER, dtype: int64

# %%
plt.scatter(cluster1.PURCHASES, cluster1.PURCHASES_FREQUENCY, c = 'red', label = 'Cluster one')
plt.scatter(cluster2['PURCHASES'], cluster2['CASH_ADVANCE'], c = 'green', label = 'Cluster two')
plt.scatter(cluster3['PURCHASES'], cluster3['CASH_ADVANCE'], c = 'purple', label = 'Cluster three')
plt.scatter(cluster4['PURCHASES'], cluster4['CASH_ADVANCE'], c = 'yellow', label = 'Cluster four')
plt.scatter(cluster5['PURCHASES'], cluster5['CASH_ADVANCE'], c = 'blue', label = 'Cluster five')


plt.title('AGGLOMERATIVE CLUSTERING')
plt.xlabel('PURCHASES')
plt.ylabel('CASH_ADVANCE')
plt.legend()

# %%
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
plt.figure(figsize=(20,7))
plt.title("Customer Dendrograms")
dend=shc.dendrogram(shc.linkage(data, method="ward"))

# %%
from sklearn.cluster import KMeans #importing our ckustering algorithm: Kmeans
model2 = KMeans(n_clusters = 5, random_state = 0) #cluster our data by choosing 5 as number of clusters
clus_labels = model2.fit(data)

# %%
clus_labels.labels_
# Out:
# array([1, 3, 3, ..., 1, 1, 1], dtype=int32)

# %%
labels = pd.DataFrame(clus_labels.labels_)
labels.head()
# Out:
#    0
# 0  1
# 1  3
# 2  3
# 3  3
# 4  1

# %%
new_df = pd.concat([data, labels], axis= 1)

# %%
new_df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
new_df = new_df.rename({0: 'Clusters'}, axis=1)

# %%
new_df.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# ...

# %%
new_df['Clusters'].value_counts()
# Out:
# 1    5661
# 3    2574
# 0     650
# 4      41
# 2      24
# Name: Clusters, dtype: int64

# %%
import matplotlib.pyplot as plt

df_0 = new_df[new_df['Clusters'] == 0]

df_1 = new_df[new_df['Clusters'] == 1]

df_2 = new_df[new_df['Clusters'] == 2]

df_3 = new_df[new_df['Clusters'] == 3]

df_4 = new_df[new_df['Clusters'] == 4]
# plt.scatter(df.Attack, df.Defense, c=df.c, alpha = 0.6, s=10)

# %%
plt.scatter(new_df["PAYMENTS"][new_df['Clusters'] == 0],new_df["BALANCE"][new_df['Clusters'] == 0],s=80,c='magenta')
plt.scatter(new_df["PAYMENTS"][new_df['Clusters'] == 1],new_df["BALANCE"][new_df['Clusters'] == 1],s=80,c='yellow')
plt.scatter(new_df["PAYMENTS"][new_df['Clusters'] == 2],new_df["BALANCE"][new_df['Clusters'] == 2],s=80,c='cyan')
plt.scatter(new_df["PAYMENTS"][new_df['Clusters'] == 3],new_df["BALANCE"][new_df['Clusters'] == 3],s=80,c='green')
plt.scatter(new_df["PAYMENTS"][new_df['Clusters'] == 4],new_df["BALANCE"][new_df['Clusters'] == 4],s=80,c='pink')

plt.show()

# %%
sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data)
    sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, sum_of_squared_distances, 'bx-', color = 'green')
plt.xlabel('K')
plt.ylabel('sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
kmeans_score = []

for i in range(2,6):
    model = KMeans(n_clusters = i)
    pre = model.fit_predict(data)
    kmeans_score = ss(data, pre)
    print(i, 'score is : ', kmeans_score)
# Out:
# 2 score is :  0.5108664173641115
# 3 score is :  0.464732926467438
# 4 score is :  0.4637623740010507
# 5 score is :  0.3931494321655998
